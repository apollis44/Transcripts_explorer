# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
from scripts.topology import (
    ensure_dir,
    get_transcripts_and_sequences,
    align_protein_sequences,
    run_deeptmhmm,
    create_membrane_topology_objects
)
from scripts.expression import (
    getting_expression_data,
    create_expression_figure_objects
)
import json
import shelve

## Variables

# Output directory
out_dir = "./files"
out_dir_for_plots = "./app/files_for_plots"

# Proteins we want to show
proteins = ["HER2", "CD20", "PROM1"]

# Email for alignment
email = "s242830@dtu.dk"

# Variables for each protein
proteins_ids = {
    "HER2": "ENSG00000141736",
    "CD20": "ENSG00000156738",
    "PROM1": "ENSG00000007062"
}

# Running the analysis for each protein
for protein in proteins:

    print(f"Processing {protein}...")
    ensure_dir(out_dir + "/" + protein)
    transcripts_id, mapping = get_transcripts_and_sequences(proteins_ids[protein], out_dir + "/" + protein)
    align_protein_sequences(email, out_dir + "/" + protein)
    run_deeptmhmm(out_dir + "/" + protein)    

    with shelve.open(out_dir_for_plots + "/transcripts_to_isoforms_mapping") as db:
        db[protein] = mapping

    membrane_topology_object = create_membrane_topology_objects(mapping, out_dir + "/" + protein)

    with shelve.open(out_dir_for_plots + "/membrane_topology_objects") as db:
        db[protein] = membrane_topology_object
    
    expression_df = getting_expression_data(transcripts_id, out_dir + "/" + protein)
    TCGA_GTEx_plotting_data = create_expression_figure_objects(out_dir + "/" + protein, expression_df, mapping)
    
    with shelve.open(out_dir_for_plots + "/TCGA_GTEx_plotting_data") as db:
        db[protein] = TCGA_GTEx_plotting_data
# Out:
# Processing CD20...
# Fetching transcripts for gene with Ensembl ID: ENSG00000156738...
# Fetching protein sequence for Ensembl IDs: ENST00000532491 ENST00000532073 ENST00000345732 ENST00000534668 ENST00000528313 ENST00000533306 ENST00000674194 ENST00000389939 ENST00000904593 ENST00000904594 ENST00000966396
# Submitting alignment job...
# Successfully submitted. Job ID: clustalo-R20260121-141431-0177-2735020-p1m
# Job status: RUNNING
# Job status: FINISHED
# Fetching alignment result...
# 2026-01-21 15:14:45,176 | INFO : Loaded project DTU/DeepTMHMM:1.0.50
# Running DeepTMHMM...
# 2026-01-21 15:14:55,879 | INFO : View the result in your browser at: https://biolib.com/results/e9a1225b-0b8e-483a-9cb2-e524a0957669/
# 2026-01-21 15:14:57,416 | INFO : Cloud: The job has been queued. Please wait...
# 2026-01-21 15:15:00,084 | INFO : Cloud: The job has been queued. Please wait...
# 2026-01-21 15:15:03,416 | INFO : Cloud: The job has been queued. Please wait...
# 2026-01-21 15:15:07,750 | INFO : Cloud: The job has been queued. Please wait...
# 2026-01-21 15:15:13,099 | INFO : Cloud: The job has been queued. Please wait...
# 2026-01-21 15:15:29,600 | INFO : Cloud: Initializing
# 2026-01-21 15:15:29,601 | INFO : Cloud: Pulling images...
# 2026-01-21 15:15:29,602 | INFO : Cloud: Computing...
# 2026-01-21 15:16:32,099 | INFO : Cloud: Computation finished
# 2026-01-21 14:16:31,755 | INFO : Extracted zip file to: output/
# 2026-01-21 14:16:31,755 | INFO : Done in 63.37 seconds
# 2026-01-21 15:16:34,248 | INFO : Cloud: Result Ready
# 2026-01-21 15:16:34,249 | INFO : Waiting for job e9a1225b-0b8e-483a-9cb2-e524a0957669 to finish...
# 2026-01-21 15:16:34,799 | INFO : Result e9a1225b-0b8e-483a-9cb2-e524a0957669 has finished.
# 2026-01-21 15:16:45,679 | INFO : Saving 3 files to ./files/CD20/DeepTMHMM_results/...
# DeepTMHMM run completed.
# Saved sequences_data.json to ./files/CD20
# Warning: Transcript ENST00000674194 not found in the database.
# Warning: Transcript ENST00000904593 not found in the database.
# Warning: Transcript ENST00000904594 not found in the database.
# Warning: Transcript ENST00000966396 not found in the database.
# Creating expression figure objects...
# Processing PROM1...
# Fetching transcripts for gene with Ensembl ID: ENSG00000007062...
# Fetching protein sequence for Ensembl IDs: ENST00000447510 ENST00000505450 ENST00000508167 ENST00000510224 ENST00000539194 ENST00000540805 ENST00000675613 ENST00000675377 ENST00000508322 ENST00000508940 ENST00000514967 ENST00000888869 ENST00000888870 ENST00000888871 ENST00000888872 ENST00000888873 ENST00000888874 ENST00000888875 ENST00000888876 ENST00000888877 ENST00000888878 ENST00000888879 ENST00000888880 ENST00000888881 ENST00000938908 ENST00000938909 ENST00000938910 ENST00000938911 ENST00000938912 ENST00000971409 ENST00000971410 ENST00000971411
# Submitting alignment job...
# Successfully submitted. Job ID: clustalo-R20260121-141723-0138-65861709-p2m
# Job status: RUNNING
# Job status: FINISHED
# Fetching alignment result...
# 2026-01-21 15:17:37,667 | INFO : Loaded project DTU/DeepTMHMM:1.0.50
# Running DeepTMHMM...
# 2026-01-21 15:17:38,391 | INFO : View the result in your browser at: https://biolib.com/results/7d1a69a2-a0d9-4cef-803f-908cd94d1a24/
# 2026-01-21 15:17:39,915 | INFO : Cloud: The job has been queued. Please wait...
# 2026-01-21 15:17:42,632 | INFO : Cloud: Initializing
# 2026-01-21 15:17:47,825 | INFO : Cloud: Pulling images...
# 2026-01-21 15:17:47,826 | INFO : Cloud: Computing...
# 2026-01-21 14:17:44,712 | INFO : Large input detected. Allocating dedicated capacity ...
# Running DeepTMHMM on 17 sequences...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 17/17 [00:06<00:00,  2.73seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 17/17 [00:22<00:00,  1.30s/seq]
#
# Step 4/4 | Generating output...
# 2026-01-21 14:18:39,106 | INFO : Done in 54.63 seconds
# 2026-01-21 15:18:40,173 | INFO : Cloud: Computation finished
# 2026-01-21 15:18:40,174 | INFO : Cloud: Result Ready
# 2026-01-21 15:18:40,175 | INFO : Waiting for job 7d1a69a2-a0d9-4cef-803f-908cd94d1a24 to finish...
# 2026-01-21 15:18:40,649 | INFO : Result 7d1a69a2-a0d9-4cef-803f-908cd94d1a24 has finished.
# 2026-01-21 15:18:41,327 | INFO : Saving 3 files to ./files/PROM1/DeepTMHMM_results/...
# DeepTMHMM run completed.
# Saved sequences_data.json to ./files/PROM1
# Warning: Transcript ENST00000675613 not found in the database.
# Warning: Transcript ENST00000675377 not found in the database.
# Warning: Transcript ENST00000888869 not found in the database.
# Warning: Transcript ENST00000888870 not found in the database.
# Warning: Transcript ENST00000888871 not found in the database.
# Warning: Transcript ENST00000888872 not found in the database.
# Warning: Transcript ENST00000888873 not found in the database.
# Warning: Transcript ENST00000888874 not found in the database.
# Warning: Transcript ENST00000888875 not found in the database.
# Warning: Transcript ENST00000888876 not found in the database.
# Warning: Transcript ENST00000888877 not found in the database.
# Warning: Transcript ENST00000888878 not found in the database.
# Warning: Transcript ENST00000888879 not found in the database.
# Warning: Transcript ENST00000888880 not found in the database.
# Warning: Transcript ENST00000888881 not found in the database.
# Warning: Transcript ENST00000938908 not found in the database.
# Warning: Transcript ENST00000938909 not found in the database.
# Warning: Transcript ENST00000938910 not found in the database.
# Warning: Transcript ENST00000938911 not found in the database.
# Warning: Transcript ENST00000938912 not found in the database.
# Warning: Transcript ENST00000971409 not found in the database.
# Warning: Transcript ENST00000971410 not found in the database.
# Warning: Transcript ENST00000971411 not found in the database.
# Creating expression figure objects...
